# %%
import pandas as pd

# %%
df_og = pd.read_csv("ShowcaseDataWinter2023.csv")
df_og
# Out:
#                price appraisal_offer  online_appraisal_flag  model_year  \
# 0       $20k to $25k      $0k to $5k                    1.0      2014.0
# 1       $15k to $20k      $0k to $5k                    0.0      2006.0
# 2       $30k to $35k    $35k to $40k                    1.0      2014.0
# 3       $35k to $40k     $5k to $10k                    1.0      2014.0
# 4       $30k to $35k    $15k to $20k                    1.0      2011.0
# ...              ...             ...                    ...         ...
# 199995  $15k to $20k    $15k to $20k                    1.0      2013.0
# 199996  $20k to $25k    $10k to $15k                    0.0      2014.0
# 199997  $30k to $35k      $0k to $5k                    0.0      2014.0
# 199998  $30k to $35k    $10k to $15k                    0.0      2012.0
# 199999  $50k to $55k    $15k to $20k                    0.0      2014.0
#
#                  mileage make   model trim_descrip body   color  ...  \
# 0       15k to 20k miles  HDT  HDT_12      Premium    E     Red  ...
# 1            100k+ miles  KQZ  KQZ_23      Premium    E  Silver  ...
# 2        5k to 10k miles  CZV  CZV_10      Premium    E   Black  ...
# 3       15k to 20k miles  IZA  IZA_19      Premium    F  Silver  ...
# 4       35k to 40k miles  HDT   HDT_8      Premium    F    Blue  ...
# ...                  ...  ...     ...          ...  ...     ...  ...
# 199995  10k to 15k miles  OFW   OFW_6      Premium    F   Black  ...
# 199996  55k to 60k miles  ARU  ARU_12  Not Premium    F   White  ...
# 199997  10k to 15k miles  AIH  AIH_13      Premium    F  Silver  ...
# 199998  50k to 55k miles  KQZ   KQZ_3  Not Premium    D   Black  ...
# 199999   5k to 10k miles  CIP  CIP_22      Premium    E   Black  ...
#
#        trim_descrip_appraisal  body_appraisal  color_appraisal  \
# 0                         NaN               D           Silver
# 1                 Not Premium               D             Gold
# 2                         NaN               E              Red
# 3                     Premium               F             Blue
# 4                 Not Premium               E            Black
# ...                       ...             ...              ...
# 199995            Not Premium               E            Black
# 199996            Not Premium               B            Black
# 199997            Not Premium               F             Gray
# 199998                Premium               D            White
# 199999                Premium               E             Blue
#
#         engine_appraisal  cylinders_appraisal  mpg_city_appraisal  \
# 0                   4.0L                    6                17.0
# 1                   4.2L                    6                16.0
# 2                   2.0L                    4                41.0
# 3                   3.0L                    6                17.0
# 4                   2.4L                    4                20.0
# ...                  ...                  ...                 ...
# 199995              1.4L                    4                26.0
# 199996              1.8L                    4                30.0
# 199997              2.4L                    4                21.0
# 199998              5.7L                    8                13.0
# 199999              5.7L                    8                18.0
#
#         mpg_highway_appraisal horsepower_appraisal fuel_capacity_appraisal  \
# 0                          21                  236                    21.0
# 1                          21                  205                    25.0
# 2                          38                  181                    10.0
# 3                          25                  230                    16.0
# 4                          29                  182                    18.0
# ...                       ...                  ...                     ...
# 199995                     31                  138                    14.0
# 199996                     39                  143                    13.0
# 199997                     30                  177                    18.0
# 199998                     19                  390                    26.0
# 199999                     25                  360                    24.0
#
#        market
# 0          13
# 1          11
# 2          13
# 3          13
# 4          16
# ...       ...
# 199995      1
# 199996      8
# 199997      3
# 199998     11
# 199999     14
#
# [200000 rows x 30 columns]

# %%
df_samp = pd.read_csv("ShowcaseSample.csv")
df_samp
# Out:
#            price appraisal_offer  online_appraisal_flag  model_year  \
# 0   $20k to $25k      $0k to $5k                      1      2014.0
# 1   $15k to $20k      $0k to $5k                      0      2006.0
# 2   $30k to $35k    $35k to $40k                      1      2014.0
# 3   $35k to $40k     $5k to $10k                      1      2014.0
# 4   $30k to $35k    $15k to $20k                      1      2011.0
# 5   $15k to $20k     $5k to $10k                      0      2013.0
# 6   $35k to $40k           $40k+                      0      2013.0
# 7   $15k to $20k     $5k to $10k                      0      2012.0
# 8   $30k to $35k    $20k to $25k                      0      2013.0
# 9   $20k to $25k      $0k to $5k                      0      2015.0
# 10  $30k to $35k     $5k to $10k                      1      2014.0
# 11  $45k to $50k      $0k to $5k                      0      2012.0
#
#              mileage make   model trim_descrip body     color  ...  \
# 0   15k to 20k miles  HDT  HDT_12      Premium    E       Red  ...
# 1        100k+ miles  KQZ  KQZ_23      Premium    E    Silver  ...
# 2    5k to 10k miles  CZV  CZV_10      Premium    E     Black  ...
# 3   15k to 20k miles  IZA  IZA_19      Premium    F    Silver  ...
# 4   35k to 40k miles  HDT   HDT_8      Premium    F      Blue  ...
# 5   35k to 40k miles  OFW  OFW_11  Not Premium    F     White  ...
# 6   20k to 25k miles  LTX  LTX_21      Premium    B      Blue  ...
# 7   30k to 35k miles  LTX  LTX_30  Not Premium    E     Black  ...
# 8   35k to 40k miles  FVQ   FVQ_4      Premium    E     Black  ...
# 9   45k to 50k miles  ARU   ARU_4  Not Premium    E      Gray  ...
# 10  15k to 20k miles  HXQ  HXQ_14      Premium    F      Blue  ...
# 11  70k to 75k miles  BDP  BDP_11          NaN    E  Burgundy  ...
#
#    trim_descrip_appraisal  body_appraisal  color_appraisal  engine_appraisal  \
# 0                     NaN               D           Silver              4.0L
# 1             Not Premium               D             Gold              4.2L
# 2                     NaN               E              Red              2.0L
# 3                 Premium               F             Blue              3.0L
# 4             Not Premium               E            Black              2.4L
# 5             Not Premium               F            Black              3.6L
# 6             Not Premium               B            Black              6.2L
# 7             Not Premium               F           Silver              1.8L
# 8                 Premium               E            Black              3.6L
# 9             Not Premium               E             Blue              4.7L
# 10                    NaN               F           Silver              3.5L
# 11                    NaN               E         Burgundy              3.5L
#
#     cylinders_appraisal  mpg_city_appraisal  mpg_highway_appraisal  \
# 0                     6                  17                     21
# 1                     6                  16                     21
# 2                     4                  41                     38
# 3                     6                  17                     25
# 4                     4                  20                     29
# 5                     6                  18                     27
# 6                     8                  16                     25
# 7                     4                  30                     39
# 8                     6                  17                     24
# 9                     8                  15                     21
# 10                    6                  21                     30
# 11                    6                  16                     21
#
#    horsepower_appraisal fuel_capacity_appraisal market
# 0                   236                      21     13
# 1                   205                      25     11
# 2                   181                      10     13
# 3                   230                      16     13
# 4                   182                      18     16
# 5                   292                      19     10
# 6                   455                      18      8
# 7                   143                      13      1
# 8                   288                      22      9
# 9                   235                      20     16
# 10                  272                      18     11
# 11                  268                      21     12
#
# [12 rows x 30 columns]

# %%
import re

# %%
data = []
for i in range(len(df_samp)):
    local = df_samp.iloc[i]['price'].replace('$', '').replace('k', '')
    gen = [int(s) for s in local.split() if s.isdigit()]
    numbers = [i * 1000 for i in gen]
    average = sum(numbers) / len(numbers)
    d = {'price_list': numbers, 'price_average' : average}
    data.append(d)
df_samp_add = pd.DataFrame(data)
df_samp_final = df_samp.join(df_samp_add)
second_col = df_samp_final.pop('price_list')
df_samp_final.insert(1, 'price_list', second_col)
third_col = df_samp_final.pop('price_average')
df_samp_final.insert(2, 'price_average', third_col)
df_samp_final
df_samp2 = df_samp_final
df_samp2
# Out:
#            price      price_list  price_average appraisal_offer  \
# 0   $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1   $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2   $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3   $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4   $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# 5   $15k to $20k  [15000, 20000]        17500.0     $5k to $10k
# 6   $35k to $40k  [35000, 40000]        37500.0           $40k+
# 7   $15k to $20k  [15000, 20000]        17500.0     $5k to $10k
# 8   $30k to $35k  [30000, 35000]        32500.0    $20k to $25k
# 9   $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 10  $30k to $35k  [30000, 35000]        32500.0     $5k to $10k
# 11  $45k to $50k  [45000, 50000]        47500.0      $0k to $5k
#
#     online_appraisal_flag  model_year           mileage make   model  \
# 0                       1      2014.0  15k to 20k miles  HDT  HDT_12
# 1                       0      2006.0       100k+ miles  KQZ  KQZ_23
# 2                       1      2014.0   5k to 10k miles  CZV  CZV_10
# 3                       1      2014.0  15k to 20k miles  IZA  IZA_19
# 4                       1      2011.0  35k to 40k miles  HDT   HDT_8
# 5                       0      2013.0  35k to 40k miles  OFW  OFW_11
# 6                       0      2013.0  20k to 25k miles  LTX  LTX_21
# 7                       0      2012.0  30k to 35k miles  LTX  LTX_30
# 8                       0      2013.0  35k to 40k miles  FVQ   FVQ_4
# 9                       0      2015.0  45k to 50k miles  ARU   ARU_4
# 10                      1      2014.0  15k to 20k miles  HXQ  HXQ_14
# 11                      0      2012.0  70k to 75k miles  BDP  BDP_11
#
#    trim_descrip  ... trim_descrip_appraisal body_appraisal color_appraisal  \
# 0       Premium  ...                    NaN              D          Silver
# 1       Premium  ...            Not Premium              D            Gold
# 2       Premium  ...                    NaN              E             Red
# 3       Premium  ...                Premium              F            Blue
# 4       Premium  ...            Not Premium              E           Black
# 5   Not Premium  ...            Not Premium              F           Black
# 6       Premium  ...            Not Premium              B           Black
# 7   Not Premium  ...            Not Premium              F          Silver
# 8       Premium  ...                Premium              E           Black
# 9   Not Premium  ...            Not Premium              E            Blue
# 10      Premium  ...                    NaN              F          Silver
# 11          NaN  ...                    NaN              E        Burgundy
#
#     engine_appraisal  cylinders_appraisal  mpg_city_appraisal  \
# 0               4.0L                    6                  17
# 1               4.2L                    6                  16
# 2               2.0L                    4                  41
# 3               3.0L                    6                  17
# 4               2.4L                    4                  20
# 5               3.6L                    6                  18
# 6               6.2L                    8                  16
# 7               1.8L                    4                  30
# 8               3.6L                    6                  17
# 9               4.7L                    8                  15
# 10              3.5L                    6                  21
# 11              3.5L                    6                  16
#
#     mpg_highway_appraisal  horsepower_appraisal  fuel_capacity_appraisal  \
# 0                      21                   236                       21
# 1                      21                   205                       25
# 2                      38                   181                       10
# 3                      25                   230                       16
# 4                      29                   182                       18
# 5                      27                   292                       19
# 6                      25                   455                       18
# 7                      39                   143                       13
# 8                      24                   288                       22
# 9                      21                   235                       20
# 10                     30                   272                       18
# 11                     21                   268                       21
#
#    market
# 0      13
# 1      11
# 2      13
# 3      13
# 4      16
# 5      10
# 6       8
# 7       1
# 8       9
# 9      16
# 10     11
# 11     12
#
# [12 rows x 32 columns]

# %%
data = []
for i in range(len(df_og)):
    local = df_og.iloc[i]['price'].replace('$', '').replace('k', '').replace('+', ' ')
    gen = [int(s) for s in local.split() if s.isdigit()]
    numbers = [i * 1000 for i in gen]
    average = sum(numbers) / len(numbers)
    d = {'price_list': numbers, 'price_average' : average}
    data.append(d)
df_add = pd.DataFrame(data)
df_full = df_og.join(df_add)
second_col = df_full.pop('price_list')
df_full.insert(1, 'price_list', second_col)
third_col = df_full.pop('price_average')
df_full.insert(2, 'price_average', third_col)
df_full
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#         online_appraisal_flag  model_year           mileage make   model  \
# 0                         1.0      2014.0  15k to 20k miles  HDT  HDT_12
# 1                         0.0      2006.0       100k+ miles  KQZ  KQZ_23
# 2                         1.0      2014.0   5k to 10k miles  CZV  CZV_10
# 3                         1.0      2014.0  15k to 20k miles  IZA  IZA_19
# 4                         1.0      2011.0  35k to 40k miles  HDT   HDT_8
# ...                       ...         ...               ...  ...     ...
# 199995                    1.0      2013.0  10k to 15k miles  OFW   OFW_6
# 199996                    0.0      2014.0  55k to 60k miles  ARU  ARU_12
# 199997                    0.0      2014.0  10k to 15k miles  AIH  AIH_13
# 199998                    0.0      2012.0  50k to 55k miles  KQZ   KQZ_3
# 199999                    0.0      2014.0   5k to 10k miles  CIP  CIP_22
#
#        trim_descrip  ... trim_descrip_appraisal body_appraisal  \
# 0           Premium  ...                    NaN              D
# 1           Premium  ...            Not Premium              D
# 2           Premium  ...                    NaN              E
# 3           Premium  ...                Premium              F
# 4           Premium  ...            Not Premium              E
# ...             ...  ...                    ...            ...
# 199995      Premium  ...            Not Premium              E
# 199996  Not Premium  ...            Not Premium              B
# 199997      Premium  ...            Not Premium              F
# 199998  Not Premium  ...                Premium              D
# 199999      Premium  ...                Premium              E
#
#        color_appraisal  engine_appraisal  cylinders_appraisal  \
# 0               Silver              4.0L                    6
# 1                 Gold              4.2L                    6
# 2                  Red              2.0L                    4
# 3                 Blue              3.0L                    6
# 4                Black              2.4L                    4
# ...                ...               ...                  ...
# 199995           Black              1.4L                    4
# 199996           Black              1.8L                    4
# 199997            Gray              2.4L                    4
# 199998           White              5.7L                    8
# 199999            Blue              5.7L                    8
#
#         mpg_city_appraisal  mpg_highway_appraisal  horsepower_appraisal  \
# 0                     17.0                     21                   236
# 1                     16.0                     21                   205
# 2                     41.0                     38                   181
# 3                     17.0                     25                   230
# 4                     20.0                     29                   182
# ...                    ...                    ...                   ...
# 199995                26.0                     31                   138
# 199996                30.0                     39                   143
# 199997                21.0                     30                   177
# 199998                13.0                     19                   390
# 199999                18.0                     25                   360
#
#         fuel_capacity_appraisal market
# 0                          21.0     13
# 1                          25.0     11
# 2                          10.0     13
# 3                          16.0     13
# 4                          18.0     16
# ...                         ...    ...
# 199995                     14.0      1
# 199996                     13.0      8
# 199997                     18.0      3
# 199998                     26.0     11
# 199999                     24.0     14
#
# [200000 rows x 32 columns]

# %%
df_og2 = df_full
df_og2
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#         online_appraisal_flag  model_year           mileage make   model  \
# 0                         1.0      2014.0  15k to 20k miles  HDT  HDT_12
# 1                         0.0      2006.0       100k+ miles  KQZ  KQZ_23
# 2                         1.0      2014.0   5k to 10k miles  CZV  CZV_10
# 3                         1.0      2014.0  15k to 20k miles  IZA  IZA_19
# 4                         1.0      2011.0  35k to 40k miles  HDT   HDT_8
# ...                       ...         ...               ...  ...     ...
# 199995                    1.0      2013.0  10k to 15k miles  OFW   OFW_6
# 199996                    0.0      2014.0  55k to 60k miles  ARU  ARU_12
# 199997                    0.0      2014.0  10k to 15k miles  AIH  AIH_13
# 199998                    0.0      2012.0  50k to 55k miles  KQZ   KQZ_3
# 199999                    0.0      2014.0   5k to 10k miles  CIP  CIP_22
#
#        trim_descrip  ... trim_descrip_appraisal body_appraisal  \
# 0           Premium  ...                    NaN              D
# 1           Premium  ...            Not Premium              D
# 2           Premium  ...                    NaN              E
# 3           Premium  ...                Premium              F
# 4           Premium  ...            Not Premium              E
# ...             ...  ...                    ...            ...
# 199995      Premium  ...            Not Premium              E
# 199996  Not Premium  ...            Not Premium              B
# 199997      Premium  ...            Not Premium              F
# 199998  Not Premium  ...                Premium              D
# 199999      Premium  ...                Premium              E
#
#        color_appraisal  engine_appraisal  cylinders_appraisal  \
# 0               Silver              4.0L                    6
# 1                 Gold              4.2L                    6
# 2                  Red              2.0L                    4
# 3                 Blue              3.0L                    6
# 4                Black              2.4L                    4
# ...                ...               ...                  ...
# 199995           Black              1.4L                    4
# 199996           Black              1.8L                    4
# 199997            Gray              2.4L                    4
# 199998           White              5.7L                    8
# 199999            Blue              5.7L                    8
#
#         mpg_city_appraisal  mpg_highway_appraisal  horsepower_appraisal  \
# 0                     17.0                     21                   236
# 1                     16.0                     21                   205
# 2                     41.0                     38                   181
# 3                     17.0                     25                   230
# 4                     20.0                     29                   182
# ...                    ...                    ...                   ...
# 199995                26.0                     31                   138
# 199996                30.0                     39                   143
# 199997                21.0                     30                   177
# 199998                13.0                     19                   390
# 199999                18.0                     25                   360
#
#         fuel_capacity_appraisal market
# 0                          21.0     13
# 1                          25.0     11
# 2                          10.0     13
# 3                          16.0     13
# 4                          18.0     16
# ...                         ...    ...
# 199995                     14.0      1
# 199996                     13.0      8
# 199997                     18.0      3
# 199998                     26.0     11
# 199999                     24.0     14
#
# [200000 rows x 32 columns]

# %%
data = []
for i in range(len(df_og2)):
    local = df_og2.iloc[i]['appraisal_offer'].replace('$', '').replace('k', '').replace('+', ' ')
    gen = [int(s) for s in local.split() if s.isdigit()]
    numbers = [i * 1000 for i in gen]
    average = sum(numbers) / len(numbers)
    d = {'appraisal_offer_list': numbers, 'appraisal_offer_average' : average}
    data.append(d)
df_add2 = pd.DataFrame(data)
df_full2 = df_og2.join(df_add2)
second_col = df_full2.pop('appraisal_offer_list')
df_full2.insert(4, 'appraisal_offer_list', second_col)
third_col = df_full2.pop('appraisal_offer_average')
df_full2.insert(5, 'appraisal_offer_average', third_col)
df_full2
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#        appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0                 [0, 5000]                   2500.0                    1.0
# 1                 [0, 5000]                   2500.0                    0.0
# 2            [35000, 40000]                  37500.0                    1.0
# 3             [5000, 10000]                   7500.0                    1.0
# 4            [15000, 20000]                  17500.0                    1.0
# ...                     ...                      ...                    ...
# 199995       [15000, 20000]                  17500.0                    1.0
# 199996       [10000, 15000]                  12500.0                    0.0
# 199997            [0, 5000]                   2500.0                    0.0
# 199998       [10000, 15000]                  12500.0                    0.0
# 199999       [15000, 20000]                  17500.0                    0.0
#
#         model_year           mileage make  ... trim_descrip_appraisal  \
# 0           2014.0  15k to 20k miles  HDT  ...                    NaN
# 1           2006.0       100k+ miles  KQZ  ...            Not Premium
# 2           2014.0   5k to 10k miles  CZV  ...                    NaN
# 3           2014.0  15k to 20k miles  IZA  ...                Premium
# 4           2011.0  35k to 40k miles  HDT  ...            Not Premium
# ...            ...               ...  ...  ...                    ...
# 199995      2013.0  10k to 15k miles  OFW  ...            Not Premium
# 199996      2014.0  55k to 60k miles  ARU  ...            Not Premium
# 199997      2014.0  10k to 15k miles  AIH  ...            Not Premium
# 199998      2012.0  50k to 55k miles  KQZ  ...                Premium
# 199999      2014.0   5k to 10k miles  CIP  ...                Premium
#
#        body_appraisal color_appraisal engine_appraisal cylinders_appraisal  \
# 0                   D          Silver             4.0L                   6
# 1                   D            Gold             4.2L                   6
# 2                   E             Red             2.0L                   4
# 3                   F            Blue             3.0L                   6
# 4                   E           Black             2.4L                   4
# ...               ...             ...              ...                 ...
# 199995              E           Black             1.4L                   4
# 199996              B           Black             1.8L                   4
# 199997              F            Gray             2.4L                   4
# 199998              D           White             5.7L                   8
# 199999              E            Blue             5.7L                   8
#
#         mpg_city_appraisal  mpg_highway_appraisal  horsepower_appraisal  \
# 0                     17.0                     21                   236
# 1                     16.0                     21                   205
# 2                     41.0                     38                   181
# 3                     17.0                     25                   230
# 4                     20.0                     29                   182
# ...                    ...                    ...                   ...
# 199995                26.0                     31                   138
# 199996                30.0                     39                   143
# 199997                21.0                     30                   177
# 199998                13.0                     19                   390
# 199999                18.0                     25                   360
#
#         fuel_capacity_appraisal  market
# 0                          21.0      13
# 1                          25.0      11
# 2                          10.0      13
# 3                          16.0      13
# 4                          18.0      16
# ...                         ...     ...
# 199995                     14.0       1
# 199996                     13.0       8
# 199997                     18.0       3
# 199998                     26.0      11
# 199999                     24.0      14
#
# [200000 rows x 34 columns]

# %%
df_og3 = df_full2

# %%
data = []
for i in range(len(df_og3)):
    local = df_og3.iloc[i]['mileage'].replace('$', '').replace('k', '').replace('+', ' ')
    gen = [int(s) for s in local.split() if s.isdigit()]
    numbers = [i * 1000 for i in gen]
    average = sum(numbers) / len(numbers)
    d = {'mileage_list': numbers, 'mileage_average' : average}
    data.append(d)
df_add3 = pd.DataFrame(data)
df_full3 = df_og3.join(df_add3)
second_col = df_full3.pop('mileage_list')
df_full3.insert(9, 'mileage_list', second_col)
third_col = df_full3.pop('mileage_average')
df_full3.insert(10, 'mileage_average', third_col)
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#        appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0                 [0, 5000]                   2500.0                    1.0
# 1                 [0, 5000]                   2500.0                    0.0
# 2            [35000, 40000]                  37500.0                    1.0
# 3             [5000, 10000]                   7500.0                    1.0
# 4            [15000, 20000]                  17500.0                    1.0
# ...                     ...                      ...                    ...
# 199995       [15000, 20000]                  17500.0                    1.0
# 199996       [10000, 15000]                  12500.0                    0.0
# 199997            [0, 5000]                   2500.0                    0.0
# 199998       [10000, 15000]                  12500.0                    0.0
# 199999       [15000, 20000]                  17500.0                    0.0
#
#         model_year           mileage    mileage_list  ...  \
# 0           2014.0  15k to 20k miles  [15000, 20000]  ...
# 1           2006.0       100k+ miles        [100000]  ...
# 2           2014.0   5k to 10k miles   [5000, 10000]  ...
# 3           2014.0  15k to 20k miles  [15000, 20000]  ...
# 4           2011.0  35k to 40k miles  [35000, 40000]  ...
# ...            ...               ...             ...  ...
# 199995      2013.0  10k to 15k miles  [10000, 15000]  ...
# 199996      2014.0  55k to 60k miles  [55000, 60000]  ...
# 199997      2014.0  10k to 15k miles  [10000, 15000]  ...
# 199998      2012.0  50k to 55k miles  [50000, 55000]  ...
# 199999      2014.0   5k to 10k miles   [5000, 10000]  ...
#
#         trim_descrip_appraisal body_appraisal color_appraisal  \
# 0                          NaN              D          Silver
# 1                  Not Premium              D            Gold
# 2                          NaN              E             Red
# 3                      Premium              F            Blue
# 4                  Not Premium              E           Black
# ...                        ...            ...             ...
# 199995             Not Premium              E           Black
# 199996             Not Premium              B           Black
# 199997             Not Premium              F            Gray
# 199998                 Premium              D           White
# 199999                 Premium              E            Blue
#
#        engine_appraisal cylinders_appraisal mpg_city_appraisal  \
# 0                  4.0L                   6               17.0
# 1                  4.2L                   6               16.0
# 2                  2.0L                   4               41.0
# 3                  3.0L                   6               17.0
# 4                  2.4L                   4               20.0
# ...                 ...                 ...                ...
# 199995             1.4L                   4               26.0
# 199996             1.8L                   4               30.0
# 199997             2.4L                   4               21.0
# 199998             5.7L                   8               13.0
# 199999             5.7L                   8               18.0
#
#        mpg_highway_appraisal  horsepower_appraisal  fuel_capacity_appraisal  \
# 0                         21                   236                     21.0
# 1                         21                   205                     25.0
# 2                         38                   181                     10.0
# 3                         25                   230                     16.0
# 4                         29                   182                     18.0
# ...                      ...                   ...                      ...
# 199995                    31                   138                     14.0
# 199996                    39                   143                     13.0
# 199997                    30                   177                     18.0
# 199998                    19                   390                     26.0
# 199999                    25                   360                     24.0
#
#         market
# 0           13
# 1           11
# 2           13
# 3           13
# 4           16
# ...        ...
# 199995       1
# 199996       8
# 199997       3
# 199998      11
# 199999      14
#
# [200000 rows x 36 columns]

# %%
df_og4 = df_full3

# %%
data = []
for i in range(len(df_og4)):
    local = df_og4.iloc[i]['mileage_appraisal'].replace('$', '').replace('k', '').replace('+', ' ')
    gen = [int(s) for s in local.split() if s.isdigit()]
    numbers = [i * 1000 for i in gen]
    average = sum(numbers) / len(numbers)
    d = {'mileage_appraisal_list': numbers, 'mileage_appraisal_average' : average}
    data.append(d)
df_add4 = pd.DataFrame(data)
df_full4 = df_og4.join(df_add4)
second_col = df_full4.pop('mileage_appraisal_list')
df_full4.insert(24, 'mileage_appraisal_list', second_col)
third_col = df_full4.pop('mileage_appraisal_average')
df_full4.insert(25, 'mileage_appraisal_average', third_col)
df_full4
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#        appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0                 [0, 5000]                   2500.0                    1.0
# 1                 [0, 5000]                   2500.0                    0.0
# 2            [35000, 40000]                  37500.0                    1.0
# 3             [5000, 10000]                   7500.0                    1.0
# 4            [15000, 20000]                  17500.0                    1.0
# ...                     ...                      ...                    ...
# 199995       [15000, 20000]                  17500.0                    1.0
# 199996       [10000, 15000]                  12500.0                    0.0
# 199997            [0, 5000]                   2500.0                    0.0
# 199998       [10000, 15000]                  12500.0                    0.0
# 199999       [15000, 20000]                  17500.0                    0.0
#
#         model_year           mileage    mileage_list  ...  \
# 0           2014.0  15k to 20k miles  [15000, 20000]  ...
# 1           2006.0       100k+ miles        [100000]  ...
# 2           2014.0   5k to 10k miles   [5000, 10000]  ...
# 3           2014.0  15k to 20k miles  [15000, 20000]  ...
# 4           2011.0  35k to 40k miles  [35000, 40000]  ...
# ...            ...               ...             ...  ...
# 199995      2013.0  10k to 15k miles  [10000, 15000]  ...
# 199996      2014.0  55k to 60k miles  [55000, 60000]  ...
# 199997      2014.0  10k to 15k miles  [10000, 15000]  ...
# 199998      2012.0  50k to 55k miles  [50000, 55000]  ...
# 199999      2014.0   5k to 10k miles   [5000, 10000]  ...
#
#         trim_descrip_appraisal body_appraisal color_appraisal  \
# 0                          NaN              D          Silver
# 1                  Not Premium              D            Gold
# 2                          NaN              E             Red
# 3                      Premium              F            Blue
# 4                  Not Premium              E           Black
# ...                        ...            ...             ...
# 199995             Not Premium              E           Black
# 199996             Not Premium              B           Black
# 199997             Not Premium              F            Gray
# 199998                 Premium              D           White
# 199999                 Premium              E            Blue
#
#        engine_appraisal cylinders_appraisal mpg_city_appraisal  \
# 0                  4.0L                   6               17.0
# 1                  4.2L                   6               16.0
# 2                  2.0L                   4               41.0
# 3                  3.0L                   6               17.0
# 4                  2.4L                   4               20.0
# ...                 ...                 ...                ...
# 199995             1.4L                   4               26.0
# 199996             1.8L                   4               30.0
# 199997             2.4L                   4               21.0
# 199998             5.7L                   8               13.0
# 199999             5.7L                   8               18.0
#
#        mpg_highway_appraisal  horsepower_appraisal  fuel_capacity_appraisal  \
# 0                         21                   236                     21.0
# 1                         21                   205                     25.0
# 2                         38                   181                     10.0
# 3                         25                   230                     16.0
# 4                         29                   182                     18.0
# ...                      ...                   ...                      ...
# 199995                    31                   138                     14.0
# 199996                    39                   143                     13.0
# 199997                    30                   177                     18.0
# 199998                    19                   390                     26.0
# 199999                    25                   360                     24.0
#
#         market
# 0           13
# 1           11
# 2           13
# 3           13
# 4           16
# ...        ...
# 199995       1
# 199996       8
# 199997       3
# 199998      11
# 199999      14
#
# [200000 rows x 38 columns]

# %%
df_og5 = df_full4

# %%
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#        appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0                 [0, 5000]                   2500.0                    1.0
# 1                 [0, 5000]                   2500.0                    0.0
# 2            [35000, 40000]                  37500.0                    1.0
# 3             [5000, 10000]                   7500.0                    1.0
# 4            [15000, 20000]                  17500.0                    1.0
# ...                     ...                      ...                    ...
# 199995       [15000, 20000]                  17500.0                    1.0
# 199996       [10000, 15000]                  12500.0                    0.0
# 199997            [0, 5000]                   2500.0                    0.0
# 199998       [10000, 15000]                  12500.0                    0.0
# 199999       [15000, 20000]                  17500.0                    0.0
#
#         model_year           mileage    mileage_list  ...  \
# 0           2014.0  15k to 20k miles  [15000, 20000]  ...
# 1           2006.0       100k+ miles        [100000]  ...
# 2           2014.0   5k to 10k miles   [5000, 10000]  ...
# 3           2014.0  15k to 20k miles  [15000, 20000]  ...
# 4           2011.0  35k to 40k miles  [35000, 40000]  ...
# ...            ...               ...             ...  ...
# 199995      2013.0  10k to 15k miles  [10000, 15000]  ...
# 199996      2014.0  55k to 60k miles  [55000, 60000]  ...
# 199997      2014.0  10k to 15k miles  [10000, 15000]  ...
# 199998      2012.0  50k to 55k miles  [50000, 55000]  ...
# 199999      2014.0   5k to 10k miles   [5000, 10000]  ...
#
#         trim_descrip_appraisal body_appraisal color_appraisal  \
# 0                          NaN              D          Silver
# 1                  Not Premium              D            Gold
# 2                          NaN              E             Red
# 3                      Premium              F            Blue
# 4                  Not Premium              E           Black
# ...                        ...            ...             ...
# 199995             Not Premium              E           Black
# 199996             Not Premium              B           Black
# 199997             Not Premium              F            Gray
# 199998                 Premium              D           White
# 199999                 Premium              E            Blue
#
#        engine_appraisal cylinders_appraisal mpg_city_appraisal  \
# 0                  4.0L                   6               17.0
# 1                  4.2L                   6               16.0
# 2                  2.0L                   4               41.0
# 3                  3.0L                   6               17.0
# 4                  2.4L                   4               20.0
# ...                 ...                 ...                ...
# 199995             1.4L                   4               26.0
# 199996             1.8L                   4               30.0
# 199997             2.4L                   4               21.0
# 199998             5.7L                   8               13.0
# 199999             5.7L                   8               18.0
#
#        mpg_highway_appraisal  horsepower_appraisal  fuel_capacity_appraisal  \
# 0                         21                   236                     21.0
# 1                         21                   205                     25.0
# 2                         38                   181                     10.0
# 3                         25                   230                     16.0
# 4                         29                   182                     18.0
# ...                      ...                   ...                      ...
# 199995                    31                   138                     14.0
# 199996                    39                   143                     13.0
# 199997                    30                   177                     18.0
# 199998                    19                   390                     26.0
# 199999                    25                   360                     24.0
#
#         market
# 0           13
# 1           11
# 2           13
# 3           13
# 4           16
# ...        ...
# 199995       1
# 199996       8
# 199997       3
# 199998      11
# 199999      14
#
# [200000 rows x 38 columns]

# %%
data = []
for i in range(len(df_samp4)):
    local = df_samp4.iloc[i]['mileage_appraisal'].replace('$', '').replace('k', '').replace('+', ' ')
    gen = [int(s) for s in local.split() if s.isdigit()]
    numbers = [i * 1000 for i in gen]
    average = sum(numbers) / len(numbers)
    d = {'mileage_appraisal_list': numbers, 'mileage_appraisal_average' : average}
    data.append(d)
df_samp_add4 = pd.DataFrame(data)
df_samp_final4 = df_samp4.join(df_samp_add4)
second_col = df_samp_final4.pop('mileage_appraisal_list')
df_samp_final4.insert(24, 'mileage_appraisal_list', second_col)
third_col = df_samp_final4.pop('mileage_appraisal_average')
df_samp_final4.insert(25, 'mileage_appraisal_average', third_col)
df_samp5 = df_samp_final4
df_samp5
# Out:
#            price      price_list  price_average appraisal_offer  \
# 0   $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1   $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2   $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3   $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4   $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# 5   $15k to $20k  [15000, 20000]        17500.0     $5k to $10k
# 6   $35k to $40k  [35000, 40000]        37500.0           $40k+
# 7   $15k to $20k  [15000, 20000]        17500.0     $5k to $10k
# 8   $30k to $35k  [30000, 35000]        32500.0    $20k to $25k
# 9   $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 10  $30k to $35k  [30000, 35000]        32500.0     $5k to $10k
# 11  $45k to $50k  [45000, 50000]        47500.0      $0k to $5k
#
#    appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0             [0, 5000]                   2500.0                      1
# 1             [0, 5000]                   2500.0                      0
# 2        [35000, 40000]                  37500.0                      1
# 3         [5000, 10000]                   7500.0                      1
# 4        [15000, 20000]                  17500.0                      1
# 5         [5000, 10000]                   7500.0                      0
# 6               [40000]                  40000.0                      0
# 7         [5000, 10000]                   7500.0                      0
# 8        [20000, 25000]                  22500.0                      0
# 9             [0, 5000]                   2500.0                      0
# 10        [5000, 10000]                   7500.0                      1
# 11            [0, 5000]                   2500.0                      0
#
#     model_year           mileage    mileage_list  ...  trim_descrip_appraisal  \
# 0       2014.0  15k to 20k miles  [15000, 20000]  ...                     NaN
# 1       2006.0       100k+ miles        [100000]  ...             Not Premium
# 2       2014.0   5k to 10k miles   [5000, 10000]  ...                     NaN
# 3       2014.0  15k to 20k miles  [15000, 20000]  ...                 Premium
# 4       2011.0  35k to 40k miles  [35000, 40000]  ...             Not Premium
# 5       2013.0  35k to 40k miles  [35000, 40000]  ...             Not Premium
# 6       2013.0  20k to 25k miles  [20000, 25000]  ...             Not Premium
# 7       2012.0  30k to 35k miles  [30000, 35000]  ...             Not Premium
# 8       2013.0  35k to 40k miles  [35000, 40000]  ...                 Premium
# 9       2015.0  45k to 50k miles  [45000, 50000]  ...             Not Premium
# 10      2014.0  15k to 20k miles  [15000, 20000]  ...                     NaN
# 11      2012.0  70k to 75k miles  [70000, 75000]  ...                     NaN
#
#    body_appraisal color_appraisal engine_appraisal cylinders_appraisal  \
# 0               D          Silver             4.0L                   6
# 1               D            Gold             4.2L                   6
# 2               E             Red             2.0L                   4
# 3               F            Blue             3.0L                   6
# 4               E           Black             2.4L                   4
# 5               F           Black             3.6L                   6
# 6               B           Black             6.2L                   8
# 7               F          Silver             1.8L                   4
# 8               E           Black             3.6L                   6
# 9               E            Blue             4.7L                   8
# 10              F          Silver             3.5L                   6
# 11              E        Burgundy             3.5L                   6
#
#    mpg_city_appraisal mpg_highway_appraisal  horsepower_appraisal  \
# 0                  17                    21                   236
# 1                  16                    21                   205
# 2                  41                    38                   181
# 3                  17                    25                   230
# 4                  20                    29                   182
# 5                  18                    27                   292
# 6                  16                    25                   455
# 7                  30                    39                   143
# 8                  17                    24                   288
# 9                  15                    21                   235
# 10                 21                    30                   272
# 11                 16                    21                   268
#
#     fuel_capacity_appraisal  market
# 0                        21      13
# 1                        25      11
# 2                        10      13
# 3                        16      13
# 4                        18      16
# 5                        19      10
# 6                        18       8
# 7                        13       1
# 8                        22       9
# 9                        20      16
# 10                       18      11
# 11                       21      12
#
# [12 rows x 38 columns]

# %%
import math

# %%
for i in range(len(df_og5)):
    if(math.isnan(df_og5.iloc[i]['online_appraisal_flag'])):
        df_og5.at[i, 'online_appraisal_flag'] = 0
df_og5
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#        appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0                 [0, 5000]                   2500.0                    1.0
# 1                 [0, 5000]                   2500.0                    0.0
# 2            [35000, 40000]                  37500.0                    1.0
# 3             [5000, 10000]                   7500.0                    1.0
# 4            [15000, 20000]                  17500.0                    1.0
# ...                     ...                      ...                    ...
# 199995       [15000, 20000]                  17500.0                    1.0
# 199996       [10000, 15000]                  12500.0                    0.0
# 199997            [0, 5000]                   2500.0                    0.0
# 199998       [10000, 15000]                  12500.0                    0.0
# 199999       [15000, 20000]                  17500.0                    0.0
#
#         model_year           mileage    mileage_list  ...  \
# 0           2014.0  15k to 20k miles  [15000, 20000]  ...
# 1           2006.0       100k+ miles        [100000]  ...
# 2           2014.0   5k to 10k miles   [5000, 10000]  ...
# 3           2014.0  15k to 20k miles  [15000, 20000]  ...
# 4           2011.0  35k to 40k miles  [35000, 40000]  ...
# ...            ...               ...             ...  ...
# 199995      2013.0  10k to 15k miles  [10000, 15000]  ...
# 199996      2014.0  55k to 60k miles  [55000, 60000]  ...
# 199997      2014.0  10k to 15k miles  [10000, 15000]  ...
# 199998      2012.0  50k to 55k miles  [50000, 55000]  ...
# 199999      2014.0   5k to 10k miles   [5000, 10000]  ...
#
#         trim_descrip_appraisal body_appraisal color_appraisal  \
# 0                          NaN              D          Silver
# 1                  Not Premium              D            Gold
# 2                          NaN              E             Red
# 3                      Premium              F            Blue
# 4                  Not Premium              E           Black
# ...                        ...            ...             ...
# 199995             Not Premium              E           Black
# 199996             Not Premium              B           Black
# 199997             Not Premium              F            Gray
# 199998                 Premium              D           White
# 199999                 Premium              E            Blue
#
#        engine_appraisal cylinders_appraisal mpg_city_appraisal  \
# 0                  4.0L                   6               17.0
# 1                  4.2L                   6               16.0
# 2                  2.0L                   4               41.0
# 3                  3.0L                   6               17.0
# 4                  2.4L                   4               20.0
# ...                 ...                 ...                ...
# 199995             1.4L                   4               26.0
# 199996             1.8L                   4               30.0
# 199997             2.4L                   4               21.0
# 199998             5.7L                   8               13.0
# 199999             5.7L                   8               18.0
#
#        mpg_highway_appraisal  horsepower_appraisal  fuel_capacity_appraisal  \
# 0                         21                   236                     21.0
# 1                         21                   205                     25.0
# 2                         38                   181                     10.0
# 3                         25                   230                     16.0
# 4                         29                   182                     18.0
# ...                      ...                   ...                      ...
# 199995                    31                   138                     14.0
# 199996                    39                   143                     13.0
# 199997                    30                   177                     18.0
# 199998                    19                   390                     26.0
# 199999                    25                   360                     24.0
#
#         market
# 0           13
# 1           11
# 2           13
# 3           13
# 4           16
# ...        ...
# 199995       1
# 199996       8
# 199997       3
# 199998      11
# 199999      14
#
# [200000 rows x 38 columns]

# %%
df_og5.iloc[7]['online_appraisal_flag']
# Out:
# 0.0

# %%
sum = 0
for i in range(len(df_og5)):
    if(math.isnan(df_og5.iloc[i]['online_appraisal_flag'])):
        sum+=1
print(sum)
# Out:
# 0

# %%
sum = 0
for i in range(len(df_og5)):
    if(math.isnan(df_og4.iloc[i]['online_appraisal_flag'])):
        sum+=1
print(sum)
# Out:
# 3834

# %%
sum = 0
for i in range(len(df_og5)):
    if(pd.isna((df_og5.iloc[i]['trim_descrip']))):
        sum+=1
print(sum)
# Out:
# 23841

# %%
df_og5
# Out:
#                price      price_list  price_average appraisal_offer  \
# 0       $20k to $25k  [20000, 25000]        22500.0      $0k to $5k
# 1       $15k to $20k  [15000, 20000]        17500.0      $0k to $5k
# 2       $30k to $35k  [30000, 35000]        32500.0    $35k to $40k
# 3       $35k to $40k  [35000, 40000]        37500.0     $5k to $10k
# 4       $30k to $35k  [30000, 35000]        32500.0    $15k to $20k
# ...              ...             ...            ...             ...
# 199995  $15k to $20k  [15000, 20000]        17500.0    $15k to $20k
# 199996  $20k to $25k  [20000, 25000]        22500.0    $10k to $15k
# 199997  $30k to $35k  [30000, 35000]        32500.0      $0k to $5k
# 199998  $30k to $35k  [30000, 35000]        32500.0    $10k to $15k
# 199999  $50k to $55k  [50000, 55000]        52500.0    $15k to $20k
#
#        appraisal_offer_list  appraisal_offer_average  online_appraisal_flag  \
# 0                 [0, 5000]                   2500.0                    1.0
# 1                 [0, 5000]                   2500.0                    0.0
# 2            [35000, 40000]                  37500.0                    1.0
# 3             [5000, 10000]                   7500.0                    1.0
# 4            [15000, 20000]                  17500.0                    1.0
# ...                     ...                      ...                    ...
# 199995       [15000, 20000]                  17500.0                    1.0
# 199996       [10000, 15000]                  12500.0                    0.0
# 199997            [0, 5000]                   2500.0                    0.0
# 199998       [10000, 15000]                  12500.0                    0.0
# 199999       [15000, 20000]                  17500.0                    0.0
#
#         model_year           mileage    mileage_list  ...  \
# 0           2014.0  15k to 20k miles  [15000, 20000]  ...
# 1           2006.0       100k+ miles        [100000]  ...
# 2           2014.0   5k to 10k miles   [5000, 10000]  ...
# 3           2014.0  15k to 20k miles  [15000, 20000]  ...
# 4           2011.0  35k to 40k miles  [35000, 40000]  ...
# ...            ...               ...             ...  ...
# 199995      2013.0  10k to 15k miles  [10000, 15000]  ...
# 199996      2014.0  55k to 60k miles  [55000, 60000]  ...
# 199997      2014.0  10k to 15k miles  [10000, 15000]  ...
# 199998      2012.0  50k to 55k miles  [50000, 55000]  ...
# 199999      2014.0   5k to 10k miles   [5000, 10000]  ...
#
#         trim_descrip_appraisal body_appraisal color_appraisal  \
# 0                          NaN              D          Silver
# 1                  Not Premium              D            Gold
# 2                          NaN              E             Red
# 3                      Premium              F            Blue
# 4                  Not Premium              E           Black
# ...                        ...            ...             ...
# 199995             Not Premium              E           Black
# 199996             Not Premium              B           Black
# 199997             Not Premium              F            Gray
# 199998                 Premium              D           White
# 199999                 Premium              E            Blue
#
#        engine_appraisal cylinders_appraisal mpg_city_appraisal  \
# 0                  4.0L                   6               17.0
# 1                  4.2L                   6               16.0
# 2                  2.0L                   4               41.0
# 3                  3.0L                   6               17.0
# 4                  2.4L                   4               20.0
# ...                 ...                 ...                ...
# 199995             1.4L                   4               26.0
# 199996             1.8L                   4               30.0
# 199997             2.4L                   4               21.0
# 199998             5.7L                   8               13.0
# 199999             5.7L                   8               18.0
#
#        mpg_highway_appraisal  horsepower_appraisal  fuel_capacity_appraisal  \
# 0                         21                   236                     21.0
# 1                         21                   205                     25.0
# 2                         38                   181                     10.0
# 3                         25                   230                     16.0
# 4                         29                   182                     18.0
# ...                      ...                   ...                      ...
# 199995                    31                   138                     14.0
# 199996                    39                   143                     13.0
# 199997                    30                   177                     18.0
# 199998                    19                   390                     26.0
# 199999                    25                   360                     24.0
#
#         market
# 0           13
# 1           11
# 2           13
# 3           13
# 4           16
# ...        ...
# 199995       1
# 199996       8
# 199997       3
# 199998      11
# 199999      14
#
# [200000 rows x 38 columns]

# %%
df_og5.to_csv('CarMax_Data_With_Null', index=False)

# %%
df_og6 = df_og5

# %%
sum = 0
for i in range(len(df_og5)):
    if(math.isnan(df_og5.iloc[i]['mpg_highway'])):
        sum+=1
print(sum)
# Out:
# 590

# %%
df_og6 = df_og6[(df_og6['mpg_highway'].notna()) & (df_og6['mpg_city'].notna()) & (df_og6['fuel_capacity'].notna()) & (df_og6['mpg_city_appraisal'].notna()) & (df_og6['mpg_highway_appraisal'].notna()) & (df_og6['fuel_capacity_appraisal'].notna())]
len(df_og6)
# Out:
# 199093

# %%
df_og6.to_csv('CarMax_Data_Without_Null', index=False)
